# %% [markdown]
# <a href="https://colab.research.google.com/github/nkalousis/lax_overlapping/blob/main/lax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime
lax_new = pd.read_excel('/content/lax_new.xlsx')
lax_old = pd.read_excel('/content/lax_old.xlsx')

# %%
# create the functions for loading individuals sheets
def load_sheet(file_name, sheet_name):
  return pd.read_excel(file_name, sheet_name=sheet_name)

new_catalog = load_sheet('/content/lax_new.xlsx', 'ΚΑΤΑΛΟΓΟΣ')
old_catalog = load_sheet('/content/lax_old.xlsx', 'ΚΑΤΑΛΟΓΟΣ')

# meat 1
meat_1_new = new_catalog.iloc[12:89].copy()
meat_1_old = old_catalog.iloc[12:89].copy()

# fish 2 but without breadish....
fish_2_new = new_catalog.iloc[91:109].copy()
fish_2_old = old_catalog.iloc[91:109].copy()

# pasta 3
pasta_3_new = new_catalog.iloc[117:166].copy()
pasta_3_old = old_catalog.iloc[117:166].copy()

# spicy 4
spicy_4_new = new_catalog.iloc[168:201].copy()
spicy_4_old = old_catalog.iloc[168:201].copy()

# veges 5
veges_5_new = new_catalog.iloc[201:271].copy()
veges_5_old = old_catalog.iloc[201:271].copy()

# cookstuff 6
cookstuff_6_new = new_catalog.iloc[272:372].copy()
cookstuff_6_old = old_catalog.iloc[272:372].copy()

# cheese 7
cheese_7_new = new_catalog.iloc[373:431].copy()
cheese_7_old = old_catalog.iloc[373:431].copy()

# frozen 8
frozen_8_new = new_catalog.iloc[432:488].copy()
frozen_8_old = old_catalog.iloc[432:488].copy()

# utilities 9
utilities_9_new = new_catalog.iloc[489:528].copy()
utilities_9_old = old_catalog.iloc[489:528].copy()

print(utilities_9_new)
# Out:
#        0                                            0.1   0.2 Unnamed: 3  \
# 489  857                                ΛΟΥΚΑΝΙΚΟΠΙΤΑΚΙ  ΚΙΛΑ       5.15
# 490  858                                     ΤΥΡΟΠΙΤΑΚΙ  ΚΙΛΑ       5.04
# 491  859                              ΖΑΜΠΟΝΟΤΥΡΟΠΙΤΑΚΙ  ΚΙΛΑ       5.15
# 492  NaN                                  ΧΡΗΣΤΙΚΑ ΕΙΔΗ   NaN        NaN
# 493  900                     ΑΛΟΥΜΙΝΟΧΑΡΤΟ 100 Μ Χ 30CM   ΤΕΜ       4.78
# 494  901                         ΑΝΤΙΚΟΛΛΗΤΙΚΟ ΧΑΡΤΙ 8Μ   ΤΕΜ        0.7
# 495  902                           ΚΟΥΤΙ ΠΙΤΣΑΣ 100 ΤΕΜ  ΣΥΣΚ       12.2
# 496  903             ΚΟΥΤΑΛΙ ΔΙΑΦΑΝΟ ΕΠΑΝΑΧΡΗΣΙΜ 100ΤΕΜ  ΣΥΣΚ        2.4
# 497  904              ΜΕΜΒΡΑΝΗ ΣΥΣΚΕΥΑΣΙΑΣ 200Μ*30CM Μ    ΤΕΜ       3.45
# 521  928                                 ΤΣΑΝΤΕΣ ΝΑΥΛΟΝ  ΚΙΛΑ        3.9
# 522  929                   ΤΡΑΠΕΖΟΜΑΝΤΗΛΑ ΧΑΡΤΙΝΑ 75ΤΕΜ  ΣΥΣΚ       9.62
# 523  930                  ΤΡΑΠΕΖΟΜΑΝΤΗΛΑ ΧΑΡΤΙΝΑ 150ΤΕΜ  ΣΥΣΚ      12.78
# 524  931                  ΤΡΑΠΕΖΟΜΑΝΤΗΛΑ ΧΑΡΤΙΝΑ 100ΤΕΜ   ΤΕΜ        9.9
# 525  932             ΜΠΩΛ ΜΑΥΡΟ ΚΑΠΑΚΙ 750ML 50 ΤΕΜΑΧΙΑ   ΤΕΜ        3.6
# 526  933                       ΚΟΥΤΙ ( ΜΕΡΙΔΑΣ) 10 ΚΙΛΑ   ΤΕΜ         10
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 489          0       5.15       0.13       0.67       5.82        NaN
# 490          0       5.04       0.13       0.66        5.7        NaN
# 491          0       5.15       0.13       0.67       5.82        NaN
# 492        NaN        NaN        NaN        NaN        NaN        NaN
# 493        0.6       4.18       0.24          1       5.18        NaN
# 494          0        0.7       0.24       0.17       0.87        NaN
# 495       0.24      11.96       0.24       2.87      14.83        NaN
# 496          0        2.4       0.24       0.58       2.98        NaN
# 497          0       3.45       0.24       0.83       4.28        NaN
# 498       0.12       5.78       0.24       1.39       7.17        NaN
# 499          0      16.36       0.24       3.93      20.29        NaN
# 500          0        0.1       0.24       0.02       0.12        NaN
# 501          0      17.17       0.24       4.12      21.29        NaN
# 502          0        0.1       0.24       0.02       0.12        NaN
# 503          0       3.23       0.24       0.78       4.01        NaN
# 504       0.02       1.08       0.24       0.26       1.34        NaN
# 505       0.01       0.51       0.24       0.12       0.63        NaN
# 506          0        0.7       0.24       0.17       0.87        NaN
# 507          0        1.2       0.24       0.29       1.49        NaN
# 508       0.23       4.27       0.24       1.02       5.29        NaN
# 509          0       1.62       0.24       0.39       2.01        NaN
# 510       0.15       2.83       0.24       0.68       3.51        NaN
# 511       0.31       5.89       0.24       1.41        7.3        NaN
# 512       0.11       1.99       0.24       0.48       2.47        NaN
# 513          0        1.5       0.24       0.36       1.86        NaN
# 514          0          5       0.24        1.2        6.2        NaN
# 515       0.11       3.64       0.24       0.87       4.51        NaN
# 516        0.3        9.7       0.24       2.33      12.03        NaN
# 517        0.3        9.7       0.24       2.33      12.03        NaN
# 518       0.39       7.41       0.24       1.78       9.19        NaN
# 519       0.29       9.21       0.24       2.21      11.42        NaN
# 520       0.15       2.75       0.24       0.66       3.41        NaN
# 521          0        3.9       0.24       0.94       4.84        NaN
# 522          0       9.62       0.24       2.31      11.93        NaN
# 523          0      12.78       0.24       3.07      15.85        NaN
# 524          0        9.9       0.24       2.38      12.28        NaN
# 525       0.11       3.49       0.24       0.84       4.33        NaN
# 526        0.3        9.7       0.24       2.33      12.03        NaN
#
#     Unnamed: 10  Unnamed: 11          Unnamed: 12 Unnamed: 13 Unnamed: 14
# 489         NaN  ΠΑΤΟΥΛΙΩΤΗΣ  2026-05-14 00:00:00       82897         NaN
# 490         NaN  ΠΑΤΟΥΛΙΩΤΗΣ  2026-05-14 00:00:00       82897         NaN
# 491         NaN  ΠΑΤΟΥΛΙΩΤΗΣ  2026-05-14 00:00:00       82897         NaN
# 492         NaN          NaN                  NaN         NaN         NaN
# 493         NaN   ΘΕΣΣΑΛΙΚΕΣ  2026-04-18 00:00:00        4836         NaN
# 494         NaN   ΘΕΣΣΑΛΙΚΕΣ  2026-04-16 00:00:00        4714         NaN
# 495        0.02         ΜΑΡΤ  2026-05-05 00:00:00       69714         NaN
# 496           0   ΘΕΣΣΑΛΙΚΕΣ  2026-02-16 00:00:00        2039         NaN
# 497         NaN   ΘΕΣΣΑΛΙΚΕΣ  2026-05-16 00:00:00        6102         NaN
# 498        0.02         ΜΑΡΤ  2026-03-26 00:00:00       68290         NaN
# 499         NaN         ΜΑΡΤ  2025-12-06 00:00:00       64573         NaN
# 500         NaN   ΘΕΣΣΑΛΙΚΕΣ  2026-04-02 00:00:00        4142         NaN
# 501         NaN          NaN                  NaN         NaN         NaN
# 502         NaN   ΘΕΣΣΑΛΙΚΕΣ  2026-03-05 00:00:00        2832         NaN
# 503         NaN         ΜΑΡΤ  2025-12-02 00:00:00       64399         NaN
# 504        0.02         ΜΑΡΤ  2026-05-02 00:00:00       69633         NaN
# 505        0.02         ΜΑΡΤ  2026-03-26 00:00:00       68290         NaN
# 506         NaN         ΜΑΡΤ  2025-06-13 00:00:00       58246         NaN
# 507         NaN         ΜΑΡΤ  2026-03-02 00:00:00       67396         NaN
# 508        0.05         ΜΑΡΤ  2025-04-16 00:00:00       56301         NaN
# 509         NaN   ΘΕΣΣΑΛΙΚΕΣ  2026-04-18 00:00:00        4836         NaN
# 510        0.05         ΜΑΡΤ  2026-01-17 00:00:00       65992         NaN
# 511        0.05         ΜΑΡΤ  2025-04-29 00:00:00       56727           Φ
# 512        0.05         ΜΑΡΤ  2025-04-29 00:00:00       56727         NaN
# 513         NaN         ΜΑΡΤ  2025-07-25 00:00:00       59904         NaN
# 514         NaN   ΘΕΣΣΑΛΙΚΕΣ  2026-01-30 00:00:00        1300         NaN
# 515        0.03         ΜΑΡΤ  2026-04-18 00:00:00       69126         NaN
# 516        0.03         ΜΑΡΤ  2026-05-05 00:00:00       69715         NaN
# 517        0.03         ΜΑΡΤ  2026-04-18 00:00:00       69126         NaN
# 518        0.05         ΜΑΡΤ  2025-04-23 00:00:00       56502         NaN
# 519        0.03         ΜΑΡΤ  2026-05-04 00:00:00       69669         NaN
# 520        0.05         ΜΑΡΤ  2025-04-23 00:00:00       56501         NaN
# 521         NaN   ΘΕΣΣΑΛΙΚΕΣ  2026-04-18 00:00:00        4836         NaN
# 522         NaN        ΜΕΤΡΟ  2026-03-11 00:00:00       54756         NaN
# 523         NaN        ΜΕΤΡΟ  2025-12-09 00:00:00       51249         NaN
# 524         NaN   ΘΕΣΣΑΛΙΚΕΣ  2026-04-18 00:00:00        4836         NaN
# 525        0.03         ΜΑΡΤ  2026-04-18 00:00:00       69126         NaN
# 526        0.03         ΜΑΡΤ  2026-05-25 00:00:00       70449         NaN

# %%
# function to compare dates and replace rows if needed
def magic(new_stuff, old_stuff, date_cell = 12):
  # compare if sizes much, if not return a warning and exit the function
  if new_stuff.shape != old_stuff.shape:
    print("Sizes do not match")
    return

  fixes =  []
  # iterate over rows
  for index, new_row in new_stuff.iterrows():
    old_row = old_stuff.loc[index] # Get the corresponding row from old_stuff
    # Your comparison logic will go here
    try:
      if new_row.iloc[date_cell] < old_row.iloc[date_cell]:
        print(f'fix needed in line {index}')
        # print(f'new {new_row}')
        # print(f'old {old_row}')
        # Replace the row in new_stuff with the corresponding row from old_stuff
        new_stuff.loc[index] = old_row
        fixes.append(new_row.iloc[0])
    except:
      print("error, but i will fix it")
      new_stuff.loc[index] = old_row
      fixes.append(new_row.iloc[0])
  print(f'fixes: {fixes}')

  return new_stuff

# %%
from typing_extensions import final
final_meat = magic(meat_1_new, meat_1_old)
final_fish = magic(fish_2_new, fish_2_old)
final_pasta = magic(pasta_3_new, pasta_3_old)
final_spicy = magic(spicy_4_new, spicy_4_old)
final_veges = magic(veges_5_new, veges_5_old)
final_cookstuff = magic(cookstuff_6_new, cookstuff_6_old)
final_cheese = magic(cheese_7_new, cheese_7_old)
final_frozen = magic(frozen_8_new, frozen_8_old)
final_utilities = magic(utilities_9_new, utilities_9_old)
# Out:
# fix needed in line 24
# fix needed in line 27
# fix needed in line 35
# fix needed in line 47
# fix needed in line 48
# fix needed in line 61
# fixes: [112, 115, 123, 146, 147, 170]
# fixes: []
# fix needed in line 162
# fix needed in line 165
# fixes: [353, 356]
# fix needed in line 186
# fixes: [419]
# fix needed in line 206
# fix needed in line 218
# error, but i will fix it
# fix needed in line 238
# fix needed in line 243
# fix needed in line 262
# fixes: [505, 517, 541, 563, 572, 591]
# fix needed in line 274
# fix needed in line 292
# fix needed in line 295
# fix needed in line 298
# fix needed in line 300
# fix needed in line 301
# fix needed in line 309
# fix needed in line 314
# fix needed in line 332
# fix needed in line 333
# fixes: [602, 620, 623, 626, 628, 629, 637, 642, 660, 661]
# error, but i will fix it
# error, but i will fix it
# fix needed in line 400
# fix needed in line 402
# fix needed in line 403
# fixes: [717, 720, 727, 729, 730]
# fix needed in line 435
# fix needed in line 439
# fixes: [803, 807]
# fix needed in line 493
# fix needed in line 508
# fix needed in line 509
# fix needed in line 518
# fixes: [900, 915, 916, 925]
